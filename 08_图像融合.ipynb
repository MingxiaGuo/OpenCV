# %% [markdown]
# # 图像融合

# %% [markdown]
# # 1. 图像融合

# %%
import cv2 #opencv的缩写为cv2
import matplotlib.pyplot as plt # matplotlib库用于绘图展示
import numpy as np   # numpy数值计算工具包

# 魔法指令，直接展示图，Jupyter notebook特有
# %matplotlib inline

# %% [markdown]
# ## 1.1 图像变换

# %%
img_cat = cv2.imread('01_Picture/01_cat.jpg')
img_dog = cv2.imread('01_Picture/03_dog.jpg')

print(img_cat.shape)
print(img_dog.shape)
img_cat+img_dog # 不同数据大小不能执行数值计算操作
# Out:
# (414, 500, 3)
# (429, 499, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/gmx/Documents/workspace/code-snippet/AI/OpenCV/08_图像融合.ipynb Cell 5 line 6
#       <a href='vscode-notebook-cell:/Users/gmx/Documents/workspace/code-snippet/AI/OpenCV/08_%E5%9B%BE%E5%83%8F%E8%9E%8D%E5%90%88.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> print(img_cat.shape)
#       <a href='vscode-notebook-cell:/Users/gmx/Documents/workspace/code-snippet/AI/OpenCV/08_%E5%9B%BE%E5%83%8F%E8%9E%8D%E5%90%88.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> print(img_dog.shape)
# ----> <a href='vscode-notebook-cell:/Users/gmx/Documents/workspace/code-snippet/AI/OpenCV/08_%E5%9B%BE%E5%83%8F%E8%9E%8D%E5%90%88.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> img_cat+img_dog
#
# ValueError: operands could not be broadcast together with shapes (414,500,3) (429,499,3)

# %%
print(img_cat.shape)
print(img_dog.shape)
img_dog = cv2.resize(img_dog,(500,414))
img_dog.shape
# Out:
# (414, 500, 3)
# (429, 499, 3)
# (414, 500, 3)

# %%
res = cv2.resize(img_dog, (0,0),fx=3,fy=1) # 横向拉伸3倍
res.shape
plt.imshow(res)

# %% [markdown]
# ## 1.2 图像融合

# %%
res = cv2.addWeighted(img_cat,0.4,img_dog,0.6,0) # img_cat 的权重为 0.4，img_dog 的权重为 0.6 ，res=0.4*img_cat+0.6*img_dog+0
print(img_dog.shape)
plt.imshow(res)
# Out:
# (414, 500, 3)
